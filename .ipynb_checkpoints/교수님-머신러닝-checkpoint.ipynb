# %%
import numpy as np
import pandas as pd
from sklearn import datasets, tree
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

from sklearn.cluster import KMeans
import matplotlib.pylab as plt

# %%
featuresData = pd.read_csv('./data/feature_regression_example.csv')

# %%
featuresData['HO_YN'] = np.where(featuresData.HOLIDAY == 'Y',1,0)
featuresData['PRO_YN'] = np.where(featuresData.PROMOTION == 'Y',1,0)

# %%
featuresData['QTY'] = featuresData.QTY.astype(float)

# %%
featuresData = featuresData[featuresData.YEARWEEK < 201653]

# %%
##상관관계 확인
corrDf = featuresData.corr()
corrResult = corrDf.reset_index()
featuresStd = 0.5
features = corrResult[(corrResult.QTY != 1) & (abs(corrResult.QTY)> featuresStd)]["index"].tolist()
label = ['QTY']

yearweekStd = 201630
trainingData_features = featuresData[featuresData.YEARWEEK <= yearweekStd][features]
trainingData_label = featuresData[featuresData.YEARWEEK <= yearweekStd][label]
testData_features = featuresData[featuresData.YEARWEEK > yearweekStd][features]
testData_label = featuresData[featuresData.YEARWEEK > yearweekStd]

# %%
model_method = tree.DecisionTreeRegressor()
model = model_method.fit(trainingData_features,trainingData_label)
predict = model.predict(testData_features)

predictData = pd.DataFrame(predict)
predictData.columns = ["PREDICT"]

testData_label = testData_label.reset_index(drop=True)

finalResultData = pd.concat([testData_label,predictData],axis=1)

# %%
## MAE
mean_absolute_error(finalResultData['QTY'],finalResultData['PREDICT'])
# Out:
# 402.7435064935065

# %%
## RMSE
mean_squared_error(finalResultData['QTY'],finalResultData['PREDICT'])
# Out:
# 364501.50973098335

# %%
##R2
r2_score(finalResultData['QTY'],finalResultData['PREDICT'])
# Out:
# 0.21932322337186283

# %%
from sklearn.externals.six import StringIO 
from IPython.display import Image 
from sklearn.tree import export_graphviz
import pydotplus

# %%
dot_data = StringIO()
export_graphviz(model,out_file=dot_data,rounded=True,special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())

# %%
##classification
np.random.seed(42)

# %%
csData = pd.read_csv('./data/customer.csv')
csData.head()
# Out:
#       deposit     stock    label
# 0  1400000000  45000000   normal
# 1  1450000000  72000000  diamond
# 2  1500000000  61000000  diamond
# 3  1370000000  56000000   normal
# 4  1920000000  48000000  diamond

# %%
featuresCol = ['deposit','stock']
labelCol = ['label']
featuresData = csData[featuresCol]
labelData = csData[labelCol]
feature_train, features_test,label_trian,label_test= train_test_split(featuresData,labelData,test_size = 0.3)

# %%
model = svm.SVC()
model.fit(feature_train,label_trian)
# Out:
# C:\Users\SMART-24\Anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
predict = model.predict(features_test)
predict
# Out:
# array(['normal', 'diamond', 'diamond', ..., 'normal', 'diamond',
#        'diamond'], dtype=object)

# %%
predictData = pd.DataFrame(predict)
predictData.columns = ["PREDICT"]
predictData.head()
# Out:
#    PREDICT
# 0   normal
# 1  diamond
# 2  diamond
# 3   normal
# 4  diamond

# %%
featureTestResult = features_test.reset_index(drop=True)
labelTestResult = label_test.reset_index(drop=True)

finalResult =pd.concat([featureTestResult,labelTestResult],axis=1)
finalResult.head(5)
# Out:
#       deposit     stock    label
# 0  1330000000  46000000   normal
# 1  1460000000  57000000  diamond
# 2  1960000000  44000000  diamond
# 3  1350000000  36000000   normal
# 4  1700000000  67000000  diamond

# %%
ac_score = accuracy_score(label_test,predict)
cl_reprot = classification_report(label_test,predict)
print("Accuracy" ,ac_score)
print("result = \n",cl_reprot)
# Out:
# Accuracy 0.9906666666666667
# result =
#               precision    recall  f1-score   support
#
#     diamond       0.98      1.00      0.99      3580
#      normal       1.00      0.98      0.99      1705
#         vip       1.00      0.97      0.99       715
#
# avg / total       0.99      0.99      0.99      6000

# %%
## 비지도 학습

# %%
studentData = pd.read_csv('./data/student_middle.csv')
name = studentData[["NAME"]]
features = studentData[["SW","DB","AND"]]

model = KMeans(n_clusters=2, algorithm="auto")
model.fit(features)

predict = pd.DataFrame(model.predict(features))
predict.columns=["PREDICT"]

result = pd.concat([name,features,predict],axis=1)
result.head()
# Out:
#      NAME  SW  DB  AND  PREDICT
# 0  ST0001  95  30    0        0
# 1  ST0002  50  50    0        0
# 2  ST0003  15  30   15        0
# 3  ST0004  90  50   20        0
# 4  ST0005  75  20   20        0

# %%
plt.scatter(result['DB'],result['AND'],c=result['PREDICT'],alpha=0.7)
